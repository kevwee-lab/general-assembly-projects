# %% [markdown]
# ## 2a) Cleaning test.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
test = pd.read_csv('datasets/test.csv')

# %%
pd.set_option('display.max_rows', len(test))
pd.set_option('display.max_columns', len(test.columns))

# %%
test.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
# ...

# %%
test.shape
# Out:
# (879, 80)

# %%
test.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
test.isnull().sum().sort_values(ascending=False)
# Out:
# Pool QC            875
# Misc Feature       838
# Alley              821
# Fence              707
# Fireplace Qu       422
# Lot Frontage       160
# Garage Cond         45
# Garage Qual         45
# Garage Yr Blt       45
# Garage Finish       45
# Garage Type         44
# Bsmt Exposure       25
# BsmtFin Type 1      25
# Bsmt Qual           25
# BsmtFin Type 2      25
# Bsmt Cond           25
# Mas Vnr Area         1
# Mas Vnr Type         1
# Electrical           1
# Overall Cond         0
# Exter Qual           0
# Exter Cond           0
# Foundation           0
# Exterior 2nd         0
# Exterior 1st         0
# Roof Matl            0
# Roof Style           0
# Year Remod/Add       0
# Year Built           0
# Sale Type            0
# Overall Qual         0
# House Style          0
# Bldg Type            0
# Condition 2          0
# Condition 1          0
# Land Slope           0
# Lot Config           0
# Utilities            0
# Land Contour         0
# Lot Shape            0
# ...

# %%
#rename columns to lowercase and remove spacing
test.columns = test.columns.str.replace(' ', '')
test.columns = test.columns.str.lower()
test.head()
# Out:
#      id        pid  mssubclass mszoning  lotfrontage  lotarea street alley  \
# 0  2658  902301120         190       RM         69.0     9142   Pave  Grvl
# 1  2718  905108090          90       RL          NaN     9662   Pave   NaN
# 2  2414  528218130          60       RL         58.0    17104   Pave   NaN
# 3  1989  902207150          30       RM         60.0     8520   Pave   NaN
# 4   625  535105100          20       RL          NaN     9500   Pave   NaN
#
#   lotshape landcontour utilities lotconfig landslope neighborhood condition1  \
# 0      Reg         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 1      IR1         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 2      IR1         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3      Reg         Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 4      IR1         Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
# ...

# %%
ords = ['lotshape', 'utilities', 'landslope', 'overallqual', 
        'overallcond', 'exterqual', 'extercond', 'bsmtqual', 'bsmtcond', 
        'bsmtexposure', 'bsmtfintype1', 'bsmtfintype2', 'heatingqc',
        'electrical', 'kitchenqual', 'functional', 'fireplacequ', 'garagefinish',
        'garagequal', 'garagecond', 'paveddrive', 'poolqc', 'fence']

test[ords].isnull().sum().sort_values(ascending=False) #ordinal variables with null values in descending order
# Out:
# poolqc          875
# fence           707
# fireplacequ     422
# garagecond       45
# garagequal       45
# garagefinish     45
# bsmtqual         25
# bsmtcond         25
# bsmtexposure     25
# bsmtfintype1     25
# bsmtfintype2     25
# electrical        1
# heatingqc         0
# kitchenqual       0
# functional        0
# paveddrive        0
# extercond         0
# exterqual         0
# overallcond       0
# overallqual       0
# landslope         0
# utilities         0
# lotshape          0
# dtype: int64

# %%
test['bsmtexposure'].mode()
# Out:
# 0    No
# dtype: object

# %%
test['bsmtexposure'] = test['bsmtexposure'].fillna('No')

# %%
test['bsmtfintype1'].mode()
# Out:
# 0    Unf
# dtype: object

# %%
test['bsmtfintype1'] = test['bsmtfintype1'].fillna('Unf')

# %%
test['bsmtfintype2'].mode()
# Out:
# 0    Unf
# dtype: object

# %%
test['bsmtfintype2'] = test['bsmtfintype2'].fillna('Unf')

# %%
test.lotshape.replace({'Reg':1, 'IR1':2, 'IR2':3, 'IR3':4}, inplace=True)
test.utilities.replace({'ELO':1, 'NoSeWa':2, 'NoSewr':3, 'AllPub':4}, inplace=True)
test.landslope.replace({'Sev':1, 'Mod':2, 'Gtl':3}, inplace=True)
test.exterqual.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.extercond.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.bsmtqual.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.bsmtcond.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.bsmtexposure.replace({'No':1, 'Mn':2, 'Av':3, 'Gd':4}, inplace=True)
test.bsmtfintype1.replace({'Unf':1, 'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6}, inplace=True)
test.bsmtfintype2.replace({'Unf':1, 'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6}, inplace=True)
test.heatingqc.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.electrical.replace({'Mix': 1, 'FuseP': 2, 'FuseF': 3, 'FuseA': 4, 'SBrkr': 5}, inplace=True)
test.kitchenqual.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.functional.replace({'Sal':1, 'Sev':2, 'Maj2':3, 'Maj1':4, 'Mod':5, 'Min2':6, 'Min1':7, 'Typ':8}, inplace=True)
test.fireplacequ.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.garagefinish.replace({'Unf':1, 'RFn':2, 'Fin':3}, inplace=True)
test.garagequal.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.garagecond.replace({'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.paveddrive.replace({'N':1, 'P':2, 'Y':3}, inplace=True)
test.poolqc.replace({'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}, inplace=True)
test.fence.replace({'MnWw': 1, 'GdWo': 2, 'MnPrv': 3, 'GdPrv': 4}, inplace=True)

test[ords] = test[ords].fillna(0) #replace null with zero

# %%
noms = ['mssubclass', 'mszoning', 'street', 'alley', 'landcontour',
        'lotconfig', 'neighborhood', 'condition1', 'condition2', 'bldgtype',
        'housestyle', 'roofstyle', 'roofmatl', 'exterior1st', 
        'exterior2nd', 'masvnrtype', 'foundation', 'heating', 'centralair',
        'garagetype', 'miscfeature', 'saletype']

test[noms].isnull().sum().sort_values(ascending=False)
# Out:
# miscfeature     838
# alley           821
# garagetype       44
# masvnrtype        1
# saletype          0
# condition2        0
# mszoning          0
# street            0
# landcontour       0
# lotconfig         0
# neighborhood      0
# condition1        0
# housestyle        0
# bldgtype          0
# roofstyle         0
# roofmatl          0
# exterior1st       0
# exterior2nd       0
# foundation        0
# heating           0
# centralair        0
# mssubclass        0
# dtype: int64

# %%
gar_check = ['garagetype', 'garagequal', 'garagefinish', 'garagecond']

test.loc[(test['garagetype'].notnull()) & (test['garagequal']==0), gar_check]
# Out:
#     garagetype  garagequal  garagefinish  garagecond
# 765     Detchd         0.0           0.0         0.0

# %%
test.loc[[765], 'garagetype'] = 'None'

# %%
test[noms] = test[noms].fillna('None')

# %%
dis_cons = [col for col in test.columns if col not in ords and col not in noms]

# %%
test[dis_cons].isnull().sum().sort_values(ascending=False)
# Out:
# lotfrontage      160
# garageyrblt       45
# masvnrarea         1
# yrsold             0
# bsmtunfsf          0
# grlivarea          0
# lowqualfinsf       0
# 2ndflrsf           0
# 1stflrsf           0
# totalbsmtsf        0
# bsmtfinsf2         0
# bsmthalfbath       0
# bsmtfinsf1         0
# yearremod/add      0
# yearbuilt          0
# lotarea            0
# pid                0
# bsmtfullbath       0
# fullbath           0
# mosold             0
# halfbath           0
# bedroomabvgr       0
# kitchenabvgr       0
# totrmsabvgrd       0
# fireplaces         0
# garagecars         0
# garagearea         0
# wooddecksf         0
# openporchsf        0
# enclosedporch      0
# 3ssnporch          0
# screenporch        0
# poolarea           0
# miscval            0
# id                 0
# dtype: int64

# %%
test['lotfrontage'] = test['lotfrontage'].fillna(test['lotfrontage'].median())

# %%
test['masvnrarea'] = test['masvnrarea'].fillna(0)

# %%
test[['garageyrblt']] = test['garageyrblt'].fillna(0)

# %%
test[dis_cons].isnull().sum().sort_values(ascending=False)
# Out:
# yrsold           0
# bsmtfinsf2       0
# grlivarea        0
# lowqualfinsf     0
# 2ndflrsf         0
# 1stflrsf         0
# totalbsmtsf      0
# bsmtunfsf        0
# bsmtfinsf1       0
# bsmthalfbath     0
# masvnrarea       0
# yearremod/add    0
# yearbuilt        0
# lotarea          0
# lotfrontage      0
# pid              0
# bsmtfullbath     0
# fullbath         0
# mosold           0
# wooddecksf       0
# miscval          0
# poolarea         0
# screenporch      0
# 3ssnporch        0
# enclosedporch    0
# openporchsf      0
# garagearea       0
# halfbath         0
# garagecars       0
# garageyrblt      0
# fireplaces       0
# totrmsabvgrd     0
# kitchenabvgr     0
# bedroomabvgr     0
# id               0
# dtype: int64

# %%
test['agesold'] = test['yrsold'] - test['yearbuilt']

# %%
test.describe().T
# Out:
#                count          mean           std          min          25%  \
# id             879.0  1.445588e+03  8.507171e+02          2.0        692.5
# pid            879.0  7.165050e+08  1.889135e+08  526302110.0  528486085.0
# mssubclass     879.0  5.827076e+01  4.221139e+01         20.0         20.0
# lotfrontage    879.0  6.933333e+01  2.137381e+01         21.0         60.0
# lotarea        879.0  1.034092e+04  1.004734e+04       1477.0       7298.5
# lotshape       879.0  1.398180e+00  5.792906e-01          1.0          1.0
# utilities      879.0  3.998862e+00  3.372916e-02          3.0          4.0
# landslope      879.0  2.944255e+00  2.576141e-01          1.0          3.0
# overallqual    879.0  6.054608e+00  1.374756e+00          2.0          5.0
# overallcond    879.0  5.565415e+00  1.128422e+00          1.0          5.0
# yearbuilt      879.0  1.970534e+03  3.040353e+01       1880.0       1954.0
# ...

# %%
drop_features = ['poolqc', 'miscfeature', 'fireplacequ', 'alley', 'fence', 'utilities', 'landscape']

# %%
dis = ['bsmtfullbath', 'bsmthalfbath', 'fullbath', 'halfbath', 'bedroomabvgr', 'kitchenabvgr', 
       'totrmsabvgrd', 'fireplaces', 'garagecars', 'agesold', 'yearbuilt', 'yrsold' ]
cons = [col for col in dis_cons if col not in dis]

# %%
drop_dis = ['kitchenabvgr', 'bsmthalfbath', 'bedroomabvgr', 'halfbath', 'bsmtfullbath', 'fireplaces', 'yrsold']
drop_features.extend(drop_dis)
drop_features
# Out:
# ['poolqc',
#  'miscfeature',
#  'fireplacequ',
#  'alley',
#  'fence',
#  'utilities',
#  'landscape',
#  'kitchenabvgr',
#  'bsmthalfbath',
#  'bedroomabvgr',
#  'halfbath',
#  'bsmtfullbath',
#  'fireplaces',
#  'yrsold']

# %%
test['total_sqft'] = test['grlivarea'] + test['totalbsmtsf'] + test['garagearea']

# %%
keep_cons = ['total_sqft', 'yearremod/add', 'masvnrarea', 'grlivarea', 'totalbsmtsf']
drop_cons = [x for x in cons if x not in keep_cons]

# %%
drop_features.extend(drop_cons)
drop_features
# Out:
# ['poolqc',
#  'miscfeature',
#  'fireplacequ',
#  'alley',
#  'fence',
#  'utilities',
#  'landscape',
#  'kitchenabvgr',
#  'bsmthalfbath',
#  'bedroomabvgr',
#  'halfbath',
#  'bsmtfullbath',
#  'fireplaces',
#  'yrsold',
#  'id',
#  'pid',
#  'lotfrontage',
#  'lotarea',
#  'bsmtfinsf1',
#  'bsmtfinsf2',
#  'bsmtunfsf',
#  '1stflrsf',
#  '2ndflrsf',
#  'lowqualfinsf',
#  'garageyrblt',
#  'garagearea',
#  'wooddecksf',
#  'openporchsf',
#  'enclosedporch',
#  '3ssnporch',
#  'screenporch',
#  'poolarea',
#  'miscval',
#  'mosold']

# %%
len(drop_features)
# Out:
# 34

# %%
drop_features.remove('id')

# %%
len(drop_features)
# Out:
# 33

# %%
test['totalqual'] = test['overallqual'] + test['exterqual'] + test['kitchenqual'] + test['bsmtqual']

# %%
keep_ords = ['totalqual', 'garagefinish']
drop_ords = [x for x in ords if x not in keep_ords]

# %%
drop_features.extend(drop_ords)

# %%
len(drop_features)
# Out:
# 55

# %%
drop_features = list(set(drop_features))

# %%
len(drop_features)
# Out:
# 51

# %%
test['exterior2nd'] = test['exterior2nd'].replace('CmentBd', 'CemntBd')

# %%
test['exterior2nd'] = test['exterior2nd'].replace('Wd Shng', 'WdShing')

# %%
test['combined_exterior'] = test['exterior1st'] + test['exterior2nd']

# %%
test.head()
# Out:
#      id        pid  mssubclass mszoning  lotfrontage  lotarea street alley  \
# 0  2658  902301120         190       RM         69.0     9142   Pave  Grvl
# 1  2718  905108090          90       RL         68.0     9662   Pave  None
# 2  2414  528218130          60       RL         58.0    17104   Pave  None
# 3  1989  902207150          30       RM         60.0     8520   Pave  None
# 4   625  535105100          20       RL         68.0     9500   Pave  None
#
#    lotshape landcontour  utilities lotconfig  landslope neighborhood  \
# 0         1         Lvl          4    Inside          3      OldTown
# 1         2         Lvl          4    Inside          3       Sawyer
# 2         2         Lvl          4    Inside          3      Gilbert
# 3         1         Lvl          4    Inside          3      OldTown
# 4         2         Lvl          4    Inside          3        NAmes
#
#   condition1 condition2 bldgtype housestyle  overallqual  overallcond  \
# ...

# %%
keep_noms = ['combined_exterior', 'mssubclass', 'neigborhood', 'foundation', 'bldgtype', 'saletype', 'housestyle', 
             'roofstyle', 'roofmatl', 'masvnrtype', 'lotconfig', 'saletype' ]
drop_noms = [x for x in noms if x not in keep_noms]
drop_noms.remove('neighborhood')

# %%
drop_features.extend(drop_noms)

# %%
drop_features = list(set(drop_features))

# %%
len(drop_features)
# Out:
# 61

# %%
keep_features = [x for x in test.columns if x not in drop_features]

# %%
len(keep_features)
# Out:
# 24

# %%
keep_features
# Out:
# ['id',
#  'mssubclass',
#  'lotconfig',
#  'neighborhood',
#  'bldgtype',
#  'housestyle',
#  'yearbuilt',
#  'yearremod/add',
#  'roofstyle',
#  'roofmatl',
#  'masvnrtype',
#  'masvnrarea',
#  'foundation',
#  'totalbsmtsf',
#  'grlivarea',
#  'fullbath',
#  'totrmsabvgrd',
#  'garagefinish',
#  'garagecars',
#  'saletype',
#  'agesold',
#  'total_sqft',
#  'totalqual',
#  'combined_exterior']

# %%
drop_features.remove('landscape')

# %%
drop_features
# Out:
# ['miscval',
#  'condition2',
#  'landcontour',
#  'mszoning',
#  'extercond',
#  'bsmtfullbath',
#  'fence',
#  'lotshape',
#  'mosold',
#  '2ndflrsf',
#  'heatingqc',
#  'exterior1st',
#  'pid',
#  'street',
#  'bsmtfinsf1',
#  'functional',
#  'miscfeature',
#  'bsmtqual',
#  'enclosedporch',
#  'utilities',
#  'screenporch',
#  'bsmtfintype2',
#  'poolarea',
#  'poolqc',
#  '3ssnporch',
#  'landslope',
#  'exterqual',
#  'bsmtcond',
#  'overallqual',
#  'bedroomabvgr',
#  'garageyrblt',
#  'condition1',
#  'exterior2nd',
#  'kitchenabvgr',
#  '1stflrsf',
#  'garagequal',
#  'alley',
#  'bsmtfintype1',
#  'centralair',
#  'garagetype',
#  'electrical',
#  'fireplacequ',
#  'fireplaces',
#  'garagecond',
#  'lowqualfinsf',
#  'yrsold',
#  'heating',
#  'garagearea',
#  'lotarea',
#  'openporchsf',
#  'bsmtunfsf',
#  'bsmtexposure',
#  'lotfrontage',
#  'bsmthalfbath',
#  'bsmtfinsf2',
#  'wooddecksf',
#  'halfbath',
#  'paveddrive',
#  'kitchenqual',
#  'overallcond']

# %%
test.drop(columns = drop_features, inplace=True)

# %%
test.head()
# Out:
#      id  mssubclass lotconfig neighborhood bldgtype housestyle  yearbuilt  \
# 0  2658         190    Inside      OldTown   2fmCon     2Story       1910
# 1  2718          90    Inside       Sawyer   Duplex     1Story       1977
# 2  2414          60    Inside      Gilbert     1Fam     2Story       2006
# 3  1989          30    Inside      OldTown     1Fam     1Story       1923
# 4   625          20    Inside        NAmes     1Fam     1Story       1963
#
#    yearremod/add roofstyle roofmatl masvnrtype  masvnrarea foundation  \
# 0           1950     Gable  CompShg       None         0.0      Stone
# 1           1977     Gable  CompShg       None         0.0     CBlock
# 2           2006     Gable  CompShg       None         0.0      PConc
# 3           2006     Gable  CompShg       None         0.0     CBlock
# 4           1963     Gable  CompShg    BrkFace       247.0     CBlock
#
#    totalbsmtsf  grlivarea  fullbath  totrmsabvgrd  garagefinish  garagecars  \
# ...

# %%
test.shape
# Out:
# (879, 24)

# %%
test.to_csv('datasets/test_final.csv')
