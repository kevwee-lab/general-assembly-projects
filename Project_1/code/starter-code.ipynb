# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The SAT and the ACT are standardized tests widely used for college admissions in the US. Our competitors ACT have seen a steady increase in participation rates, and in 2012, surpassed the SAT for the first time in terms of total test takers. As an employee of the College Board which administers the SAT, my role is to perform exploratory data analysis on the 2017/2018 ACT and SAT data to figure out the following: <BR>
# Where we can best spend money to improve SAT participation rates in the US?

# %% [markdown]
# ## Executive Summary
#
# The dataset contains average test scores, total mean/composite test scores and participation rates from 2017 to 2018.
#
# #### Methodology
#
# The workflow for the data analysis was as follows:
# 1) Datasets were read and converted into a **Pandas DataFrame**
# 2) **Data cleaning** was conducted to ensure that there were no errors in the values of the data and that all the datatypes were correctly cast.
# 3) All datasets were then merged into a single dataframe.
# 4) **Exploratory data analysis** was conducted to make estimates and observe trends in the data.
# 5) **Visualizations** were then made to help reinforce the observations, e.g. heatmaps, subplots, histograms, scatterplots and boxplots.
# 6) **Descriptive and inferential statistical analysis** was then conducted to desctibe the distributions.
# 7) Combined with research about the SAT and ACT from external sources, recommendations for the College Board were then compiled and presented.
#
# #### Findings
# 1) **Public policy is a key driver to increasing SAT participation rates**: As we have seen in the case of Colorado and Illinois, working with education boards or department of education in the respective states have helped to push SAT participation rates greatly. <br> <br>
# 2) **Increased participation rates are negatively correlated to test scores**: One of the reasons could be due to high achieving students taking both tests to boost their college admission chances. Another possible reason could be that with sudden mandates or changes in contracts, schools need time to adjust to the new test and prep their students to take it. This is why scores could dip in the short term. More data on scores over time would be required to examine if this is true.<br><br>
# 3) **SAT participation rate has seen some moderate success**: More states achieved 90% to 100% participation rates for SAT in 2018, from 7 in 2017 to 10 in 2018. More can be done to increase the participation rate in other states.
#
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_2017 = pd.read_csv('C:/Users/weezs/dsi-roughpaper/project_1/data/sat_2017.csv')
act_2017 = pd.read_csv('C:/Users/weezs/dsi-roughpaper/project_1/data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
sat_2017.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
sat_2017.tail(10)
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 41   South Dakota            3%                                 612   603
# 42      Tennessee            5%                                 623   604
# 43          Texas           62%                                 513   507
# 44           Utah            3%                                 624   614
# 45        Vermont           60%                                 562   551
# 46       Virginia           65%                                 561   541
# 47     Washington           64%                                 541   534
# 48  West Virginia           14%                                 558   528
# 49      Wisconsin            3%                                 642   649
# 50        Wyoming            3%                                 626   604
#
#     Total
# 41   1216
# 42   1228
# 43   1020
# 44   1238
# 45   1114
# 46   1102
# 47   1075
# 48   1086
# 49   1291
# 50   1230

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sat_2017.shape
# Out:
# (51, 5)

# %%
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
act_2017.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %%
act_2017.tail(10)
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 42   South Dakota           80%     20.7  21.5     22.3     22.0      21.8
# 43      Tennessee          100%     19.5  19.2     20.1     19.9      19.8
# 44          Texas           45%     19.5  20.7     21.1     20.9      20.7
# 45           Utah          100%     19.5  19.9     20.8     20.6      20.3
# 46        Vermont           29%     23.3  23.1     24.4     23.2      23.6
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_2017.shape
# Out:
# (52, 7)

# %%
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: <br>
# **SAT2017** <br>
#
# Data comprises 51 rows and 5 columns. Every row is an entry for a state. The columns are named as follows: <br>
# 1)'State': States in US (object/string) <br>
# 2)'Participation': Participation rate (object/%) <br>
# 3)'Evidence-Based Reading and Writing': Score (int) <br>
# 4)'Math': Score (int) <br>
# 5)'Total': Combined Score ('Evidence Based Reading and Writing' + 'Math'/ int) <br>
#
# The mean scores for:
# 1)'Evidence-Based Reading and Writing' ~ 569 <br>
# 2)'Math' ~ 547 <br>
# 3)'Total' ~ 1126 <br>
# (*Total is inaccurate, meaning there might be discrepancies in this column to correct*) <br>
#
#
# https://www.khanacademy.org/test-prep/sat/new-sat-tips-planning/new-sat-about-sat/a/scoring-on-the-redesigned-sat#:~:text=The%20highest%20composite%20score%20for,to%20get%20your%20overall%20score.
#
#
# **ACT2017** <br>
#
# Data comprises 52 rows and 7 columns. Every row is an entry for a state. The columns are named as follows: <br>
# 1)'State': States in US (object/string) <br>
# (*There is an additional row of data called 'National' which might not be helpful*) <br>
# 2)'Participation': Participation rate (object/%) <br>
# 3)'English': Score (int) <br>
# 4)'Math': Score (int) <br>
# 5)'Reading': Score (int) <br>
# 6)'Science': Score (int) <br>
# 7)'Composite': Score (Average of English, Math, Reading, Science scores/object) <br>
# (*Some Composite averages do not look correct, meaning there might be discrepancies in this column to correct. Also average should be int and not object/string*)
#
# The mean scores for: <br>
# 1)English: ~20 <br>
# 2)Math: ~21 <br>
# 3)Reading: ~22 <br>
# 4)Science: ~21 <br>
#
# https://www.princetonreview.com/college-advice/act-score-chart#:~:text=Your%20composite%20score%2C%20or%20overall,to%20the%20nearest%20whole%20number) <br>
# https://en.wikipedia.org/wiki/ACT_(test)

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Based on the exploration of both datasets using the isnull method, the data looks complete, meaning there are no null value in both datasets (isnull sum is 0 for all columns). However, there might be some inaccuracies in the data that need to be addressed.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: <br>
# **For SAT:** Scores range from 200 to 800, based on data it is 52. <br>
# 1)When looking at the data for the state of Maryland, compared to the source data,52 turns out to be an entry error. Math score should be 524 instead of 52<br>
# 2)Data type for participation is an object. Need to convert it to float and remove the special character '%'. <br>
#
# **For ACT**: Scores range from 1 to 36, based on data it is 2.3. <br>
# 1)Similar to SAT 2017 data, there is an entry error for the state of Maryland.Science score should be 23.2 instead of 2.3. <br>
# 2)For Wyoming, composite score has an alphabet 'x' beside it. <br>
# 3)Data type for composite score and participation are objects. Need to convert to float and remove special characters. <br>
# 4)Remove National average row as it does not seem necessary or helpful.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
sat_2017['Math'].replace(52, 524, inplace=True) #Correct math score for Maryland

# %%
act_2017['Science'].replace(2.3, 23.2, inplace=True) # replace wrong values in science and composite
act_2017['Composite'].replace('20.2x', '20.2', inplace=True)

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: For both ACT and SAT data, participation should be expressed as float and not object/string. <br>
# For ACT data, composite score should be a float instead of object. <br>
# For SAT data, scores are of int type instead of float like ACT scores. <br>

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
sat_2017['Participation'] = sat_2017['Participation'].str.replace('%', '').astype(float) # change data type to float
sat_2017['Participation'] = sat_2017['Participation'].map(lambda x:x/100)

# %%
act_2017['Composite'] = act_2017['Composite'].astype(float) # change composite score and participation data type to float
act_2017['Participation'] = act_2017['Participation'].str.replace('%', '').astype(float)
act_2017['Participation'] = act_2017['Participation'].map(lambda x:x/100)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
sat_2017.rename(columns={'State':'state',
                         'Participation':'sat2017_part_rate',
                         'Evidence-Based Reading and Writing':'sat2017_read_write',
                         'Math' : 'sat2017_math',
                         'Total': 'sat2017_total'
                        }, inplace=True)

# %%
act_2017.rename(columns={'State':'state',
                         'Participation':'act2017_part_rate',
                         'English':'act2017_eng',
                         'Math' : 'act2017_math',
                         'Reading': 'act2017_read',
                         'Science' : 'act_2017_sci',
                         'Composite': 'act_2017_avgscore'
                        }, inplace=True)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|States in the US|
# |sat_2017_part_rate|float|SAT|Statewide participation rate in 2017 SAT|
# |sat2017_read_write|int|SAT|2017 Mean SAT score of state for evidence-based reading and writing|
# |sat2017_math|int|SAT|2017 Mean SAT score of state for math|
# |sat2017_total|int|SAT|2017 Mean total SAT score of state|
# |act_2017_part_rate|float|ACT|Statewide participation rate in 2017 ACT|
# |act_2017_eng|float|ACT|2017 Mean ACT score of state for English|
# |act_2017_math|float|ACT|2017 Mean ACT score of state for Math|
# |act_2017_read|float|ACT|2017 Mean ACT score of state for Reading|
# |act_2017_sci|float|ACT|2017 Mean ACT score of state for Science|
# |act_2017_avgscore|float|ACT|2017 Mean composite ACT score of state|
# |sat_2018_part_rate|float|SAT|Statewide participation rate in 2018 SAT|
# |sat2018_read_write|int|SAT|2018 Mean SAT score of state for evidence-based reading and writing|
# |sat2018_math|int|SAT|2018 Mean SAT score of state for math|
# |sat2018_total|int|SAT|2018 Mean total SAT score of state|
# |act_2018_part_rate|float|ACT|Statewide participation rate in 2018 ACT|
# |act_2018_eng|float|ACT|2018 Mean ACT score of state for English|
# |act_2018_math|float|ACT|2018 Mean ACT score of state for Math|
# |act_2018_read|float|ACT|2018 Mean ACT score of state for Reading|
# |act_2018_sci|float|ACT|2018 Mean ACT score of state for Science|
# |act_2018_avgscore|float|ACT|2018 Mean composite ACT score of state|
# |sat_part_change|float|SAT|change in participation rate for SAT|
# |act_part_change|float|ACT|change in participation rate for ACT|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
act_2017.drop(0, inplace=True) #remove national average

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:
sat_act_2017 = sat_2017.merge(act_2017, how='outer', on=['state']) #only outer joins merge all columns in both datasets together

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
sat_act_2017.to_csv('../data/sat_act_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat_2018 = pd.read_csv('../data/sat_2018.csv')
act_2018 = pd.read_csv('../data/act_2018_updated.csv') #read 2018 data

# %%
sat_2018.dtypes #determine whether there are any data types that need to be changed
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_2018.head() #look at the first 5 entries
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2018.tail() #look at last 5 entries
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           68%                                 567   550
# 47     Washington           69%                                 543   538
# 48  West Virginia           28%                                 513   486
# 49      Wisconsin            3%                                 641   653
# 50        Wyoming            3%                                 633   625
#
#     Total
# 46   1117
# 47   1081
# 48    999
# 49   1294
# 50   1257

# %%
sat_2018.isnull().sum() #determine if there are null values that need to be replaced
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat_2018.describe() #look at the description to determine if there are any values that look odd
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
act_2018.dtypes #determine if there are data types that need to be changed
# Out:
# State                             object
# Percentage of Students Tested      int64
# Average Composite Score          float64
# Average English Score            float64
# Average Math Score               float64
# Average Reading Score            float64
# Average Science Score            float64
# dtype: object

# %%
act_2018.head() #look at the first 5 entries
# Out:
#         State  Percentage of Students Tested  Average Composite Score  \
# 0     Alabama                            100                     19.1
# 1      Alaska                             33                     20.8
# 2     Arizona                             66                     19.2
# 3    Arkansas                            100                     19.4
# 4  California                             27                     22.7
#
#    Average English Score  Average Math Score  Average Reading Score  \
# 0                   18.9                18.3                   19.6
# 1                   19.8                20.6                   21.6
# 2                   18.2                19.4                   19.5
# 3                   19.1                18.9                   19.7
# 4                   22.5                22.5                   23.0
#
#    Average Science Score
# 0                   19.0
# 1                   20.7
# 2                   19.2
# 3                   19.4
# ...

# %%
act_2018.tail() #look at the last 5 entries
# Out:
#             State  Percentage of Students Tested  Average Composite Score  \
# 46       Virginia                             24                     23.9
# 47     Washington                             24                     22.2
# 48  West Virginia                             65                     20.3
# 49      Wisconsin                            100                     20.5
# 50        Wyoming                            100                     20.0
#
#     Average English Score  Average Math Score  Average Reading Score  \
# 46                   23.8                23.3                   24.7
# 47                   21.4                22.2                   22.7
# 48                   19.8                19.4                   21.3
# 49                   19.8                20.3                   20.6
# 50                   19.0                19.7                   20.6
#
#     Average Science Score
# 46                   23.5
# 47                   22.0
# ...

# %%
act_2018.isnull().sum() #determine if there are null values that need to be replaced
# Out:
# State                            0
# Percentage of Students Tested    0
# Average Composite Score          0
# Average English Score            0
# Average Math Score               0
# Average Reading Score            0
# Average Science Score            0
# dtype: int64

# %%
act_2018.describe() #look at the description to determine if there are any values that look odd
# Out:
#        Percentage of Students Tested  Average Composite Score  \
# count                      51.000000                51.000000
# mean                       61.647059                21.486275
# std                        34.080976                 2.106278
# min                         7.000000                17.700000
# 25%                        28.500000                19.950000
# 50%                        66.000000                21.300000
# 75%                       100.000000                23.550000
# max                       100.000000                25.600000
#
#        Average English Score  Average Math Score  Average Reading Score  \
# count              51.000000           51.000000              51.000000
# mean               20.988235           21.125490              22.015686
# std                 2.446356            2.035765               2.167245
# min                16.600000           17.800000              18.000000
# ...

# %%
sat_2018['Participation'] = sat_2018['Participation'].str.replace('%', "").astype(float) # convert values in Participation into float
sat_2018['Participation'] = sat_2018['Participation'].map(lambda x:x/100)  #apply function to entire column to accurately represent % as float

# %%
sat_2018.rename(columns={'State':'state',
                         'Participation':'sat2018_part_rate',
                         'Evidence-Based Reading and Writing':'sat2018_read_write',
                         'Math' : 'sat2018_math',
                         'Total': 'sat2018_total'
                        }, inplace=True) #rename columns

# %%
act_2018['Percentage of Students Tested'] = act_2018['Percentage of Students Tested'].astype(float) # convert values from int to float
act_2018['Percentage of Students Tested'] = act_2018['Percentage of Students Tested'].map(lambda x:x/100)   #apply function to entire column to accurately represent % as float

# %%
act_2018.rename(columns={'State':'state',
                         'Percentage of Students Tested':'act2018_part_rate',
                         'Average English Score':'act2018_eng',
                         'Average Math Score' : 'act2018_math',
                         'Average Reading Score': 'act2018_read',
                         'Average Science Score' : 'act_2018_sci',
                         'Average Composite Score': 'act_2018_avgscore'
                        }, inplace=True)

# %%
#merge 2018 datasets

sat_act_2018 = sat_2018.merge(act_2018, how='outer', on=['state']) #merge data on state

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
final = sat_act_2017.merge(sat_act_2018, how='outer', on=['state']) #merge data on state

# %%
final.to_csv('../data/final.csv')  #save data to path

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().T
# Out:
#                     count         mean        std     min       25%      50%  \
# sat2017_part_rate    51.0     0.398039   0.352766    0.02     0.040     0.38
# sat2017_read_write   51.0   569.117647  45.666901  482.00   533.500   559.00
# sat2017_math         51.0   556.882353  47.121395  468.00   523.500   548.00
# sat2017_total        51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# act2017_part_rate    51.0     0.652549   0.321408    0.08     0.310     0.69
# act2017_eng          51.0    20.931373   2.353677   16.30    19.000    20.70
# act2017_math         51.0    21.182353   1.981989   18.00    19.400    20.90
# act2017_read         51.0    22.013725   2.067271   18.10    20.450    21.80
# act_2017_sci         51.0    21.450980   1.739353   18.20    19.950    21.30
# act_2017_avgscore    51.0    21.519608   2.020695   17.80    19.800    21.40
# sat2018_part_rate    51.0     0.457451   0.373143    0.02     0.045     0.52
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def std_dev(data):
    mean= sum(data) / len(data)
    deviation = [(x - mean) ** 2 for x in data] 
    variance = sum(deviation) / len(data)
    return variance ** 0.5

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:
sd = {column: std_dev(final[column]) for column in final if column !='state'}
sd
# Out:
# {'sat2017_part_rate': 0.3492907076664507,
#  'sat2017_read_write': 45.21697020437866,
#  'sat2017_math': 46.65713364485503,
#  'sat2017_total': 91.58351056778743,
#  'act2017_part_rate': 0.3182417575123181,
#  'act2017_eng': 2.3304876369363363,
#  'act2017_math': 1.9624620273436781,
#  'act2017_read': 2.0469029314842646,
#  'act_2017_sci': 1.7222161451443676,
#  'act_2017_avgscore': 2.000786081581989,
#  'sat2018_part_rate': 0.3694661922353942,
#  'sat2018_read_write': 47.03460978357609,
#  'sat2018_math': 47.30194550378352,
#  'sat2018_total': 93.22742384464433,
#  'act2018_part_rate': 0.33745194881997503,
#  'act_2018_avgscore': 2.0855261815801147,
#  'act2018_eng': 2.4222536143202795,
#  'act2018_math': 2.015707255555717,
#  'act2018_read': 2.145891884510421,
#  'act_2018_sci': 1.8516885484833543}

# %%
new_sd = {column: np.std(final[column]) for column in final if column !='state'}
new_sd
# Out:
# {'sat2017_part_rate': 0.3492907076664507,
#  'sat2017_read_write': 45.21697020437866,
#  'sat2017_math': 46.65713364485503,
#  'sat2017_total': 91.58351056778743,
#  'act2017_part_rate': 0.3182417575123181,
#  'act2017_eng': 2.3304876369363363,
#  'act2017_math': 1.9624620273436781,
#  'act2017_read': 2.0469029314842646,
#  'act_2017_sci': 1.7222161451443676,
#  'act_2017_avgscore': 2.000786081581989,
#  'sat2018_part_rate': 0.3694661922353942,
#  'sat2018_read_write': 47.03460978357609,
#  'sat2018_math': 47.30194550378352,
#  'sat2018_total': 93.22742384464433,
#  'act2018_part_rate': 0.33745194881997503,
#  'act_2018_avgscore': 2.0855261815801147,
#  'act2018_eng': 2.4222536143202795,
#  'act2018_math': 2.015707255555717,
#  'act2018_read': 2.145891884510421,
#  'act_2018_sci': 1.8516885484833543}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# **Answer**<br>
# The calculations from my function and numpy std are the same. However, both calculations differ from the pandas describe method, though not by a lot.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# # Participation for SAT and Observations

# %%
#2017 SAT Highest participation rate
final.sort_values('sat2017_part_rate', ascending=False)[['state', 'sat2017_part_rate']].head(10)
# Out:
#                    state  sat2017_part_rate
# 8   District of Columbia               1.00
# 22              Michigan               1.00
# 6            Connecticut               1.00
# 7               Delaware               1.00
# 29         New Hampshire               0.96
# 19                 Maine               0.95
# 12                 Idaho               0.93
# 9                Florida               0.83
# 21         Massachusetts               0.76
# 39          Rhode Island               0.71

# %%
#2017 SAT Lowest participation rate
final.sort_values('sat2017_part_rate')[['state', 'sat2017_part_rate']].head(10)
# Out:
#            state  sat2017_part_rate
# 34  North Dakota               0.02
# 24   Mississippi               0.02
# 15          Iowa               0.02
# 25      Missouri               0.03
# 44          Utah               0.03
# 41  South Dakota               0.03
# 27      Nebraska               0.03
# 49     Wisconsin               0.03
# 23     Minnesota               0.03
# 50       Wyoming               0.03

# %% [markdown]
# For **2017 SAT**, the top 5 states with highest participation rates are: <br>
# * District of Columbia
# * Michigan
# * Connecticut
# * Delaware
# * New Hampshire <br>
#
# The bottom 5 states with the lowest participation rates are: <br>
# * North Dakota
# * Mississippi
# * Iowa
# * Missouri
# * Utah

# %%
#2018 SAT Highest participation rate
final.sort_values('sat2018_part_rate', ascending=False)[['state', 'sat2018_part_rate']].head(10)
# Out:
#                    state  sat2018_part_rate
# 5               Colorado               1.00
# 6            Connecticut               1.00
# 7               Delaware               1.00
# 22              Michigan               1.00
# 12                 Idaho               1.00
# 19                 Maine               0.99
# 13              Illinois               0.99
# 39          Rhode Island               0.97
# 29         New Hampshire               0.96
# 8   District of Columbia               0.92

# %%
#2018 SAT Lowest participation rate
final.sort_values('sat2018_part_rate')[['state', 'sat2018_part_rate']].head(10)
# Out:
#            state  sat2018_part_rate
# 34  North Dakota               0.02
# 50       Wyoming               0.03
# 41  South Dakota               0.03
# 27      Nebraska               0.03
# 49     Wisconsin               0.03
# 24   Mississippi               0.03
# 15          Iowa               0.03
# 44          Utah               0.04
# 23     Minnesota               0.04
# 18     Louisiana               0.04

# %% [markdown]
# For **2018 SAT**, the top 5 states with highest participation rates are: <br>
# * Colorado
# * Connecticut
# * Delaware
# * Michigan
# * Idaho <br>
#
# The bottom 5 states with the lowest participation rates are: <br>
# * North Dakota
# * Wyoming
# * South Dakota
# * Nebraska
# * Winsconsin

# %%
final.loc[final['sat2017_part_rate'] == 1.00, ['state']].count()
#find out how many states achieved 100% participation
# Out:
# state    4
# dtype: int64

# %%
final.loc[final['sat2018_part_rate'] == 1.00, ['state']].count()
#find out how many states achieved 100% participation
# Out:
# state    5
# dtype: int64

# %% [markdown]
# ### **SAT Participation observations** <br>
# North Dakota has the lowest participation (2%) for 2017 and 2018. Michigan, Connecticut, and Delaware have the highest participation (100%) for 2017 and 2018. <br>
# Idaho showed an improvement in participation from 93% in 2017 to 100% in 2018.
#
# It is also worth noting that in 2018, 5 states attained 100% participation rate compared to 4 states in 2017. District of Columbia dropped out of the top 10 states in terms of participation rate. Colorado and Idaho achieved 100% participation rate in 2018.

# %% [markdown]
# # Participation for ACT and Observations

# %%
#2017 ACT Highest participation rate
final.sort_values('act2017_part_rate', ascending=False)[['state', 'act2017_part_rate']].head(10)
# Out:
#              state  act2017_part_rate
# 0          Alabama                1.0
# 17        Kentucky                1.0
# 49       Wisconsin                1.0
# 44            Utah                1.0
# 42       Tennessee                1.0
# 40  South Carolina                1.0
# 36        Oklahoma                1.0
# 33  North Carolina                1.0
# 28          Nevada                1.0
# 26         Montana                1.0

# %%
#2017 ACT Lowest participation rate
final.sort_values('act2017_part_rate')[['state', 'act2017_part_rate']].head(10)
# Out:
#             state  act2017_part_rate
# 19          Maine               0.08
# 29  New Hampshire               0.18
# 7        Delaware               0.18
# 39   Rhode Island               0.21
# 38   Pennsylvania               0.23
# 20       Maryland               0.28
# 45        Vermont               0.29
# 21  Massachusetts               0.29
# 22       Michigan               0.29
# 46       Virginia               0.29

# %% [markdown]
# For **2017 ACT**, the top 5 states with highest participation rates are: <br>
# * Alabama
# * Kentucky
# * Winsconsin
# * Utah
# * Tennessee <br>
#
# The bottom 5 states with the lowest participation rates are: <br>
# * Maine
# * New Hampshire
# * Delaware
# * Rhode Island
# * Pennsylvania

# %%
#2018 ACT Highest participation rate
final.sort_values('act2018_part_rate', ascending=False)[['state', 'act2018_part_rate']].head(10)
# Out:
#              state  act2018_part_rate
# 0          Alabama                1.0
# 17        Kentucky                1.0
# 49       Wisconsin                1.0
# 44            Utah                1.0
# 42       Tennessee                1.0
# 40  South Carolina                1.0
# 36        Oklahoma                1.0
# 35            Ohio                1.0
# 33  North Carolina                1.0
# 28          Nevada                1.0

# %%
#2018 ACT Lowest participation rate
final.sort_values('act2018_part_rate')[['state', 'act2018_part_rate']].head(10)
# Out:
#             state  act2018_part_rate
# 19          Maine               0.07
# 39   Rhode Island               0.15
# 29  New Hampshire               0.16
# 7        Delaware               0.17
# 38   Pennsylvania               0.20
# 22       Michigan               0.22
# 47     Washington               0.24
# 45        Vermont               0.24
# 46       Virginia               0.24
# 21  Massachusetts               0.25

# %% [markdown]
# For **2018 ACT**, the top 5 states with highest participation rates are: <br>
# * Alabama
# * Kentucky
# * Winsconsin
# * Utah
# * Tennessee <br>
#
# The bottom 5 states with the lowest participation rates are: <br>
# * Maine
# * Rhode Island
# * New Hampshire
# * Delaware
# * Pennsylvania

# %%
final.loc[final['act2017_part_rate'] == 1.00, ['state']].count() 
#find out how many states achieved 100% participation
# Out:
# state    17
# dtype: int64

# %%
final.loc[final['act2018_part_rate'] == 1.00, ['state']].count() 
#find out how many states achieved 100% participation
# Out:
# state    17
# dtype: int64

# %% [markdown]
# ### **ACT Participation observations** <br>
#
# There does not seem to be much change in terms of the 2017 and 2018 top and bottom 5 states. However, it seems that for the bottom 5 states, participation rates have dropped in 2018.
#
# It is worth noting that:
# * there was no change in number of states achieving 100% participation rate in 2017 and 2018 and
# * that there seem to be more states taking up the ACT than the SAT.

# %% [markdown]
# # SAT mean score and Observations

# %%
#2017 SAT highest total mean score
final.sort_values('sat2017_total', ascending=False)[['state', 'sat2017_part_rate', 'sat2017_total']].head(10)
# Out:
#            state  sat2017_part_rate  sat2017_total
# 23     Minnesota               0.03           1295
# 49     Wisconsin               0.03           1291
# 15          Iowa               0.02           1275
# 25      Missouri               0.03           1271
# 16        Kansas               0.04           1260
# 34  North Dakota               0.02           1256
# 27      Nebraska               0.03           1253
# 17      Kentucky               0.04           1247
# 24   Mississippi               0.02           1242
# 44          Utah               0.03           1238

# %%
#2017 SAT lowest total mean score
final.sort_values('sat2017_total')[['state','sat2017_part_rate', 'sat2017_total']].head(10)
# Out:
#                    state  sat2017_part_rate  sat2017_total
# 8   District of Columbia               1.00            950
# 7               Delaware               1.00            996
# 12                 Idaho               0.93           1005
# 22              Michigan               1.00           1005
# 19                 Maine               0.95           1012
# 9                Florida               0.83           1017
# 43                 Texas               0.62           1020
# 6            Connecticut               1.00           1041
# 36              Oklahoma               0.07           1047
# 10               Georgia               0.61           1050

# %% [markdown]
# For **2017 SAT**, the top 5 states with highest mean scores are: <br>
# * Minnesota
# * Winsconsin
# * Iowa
# * Missouri
# * Kansas <br>
#
# The bottom 5 states with the lowest mean scores are: <br>
# * District of Columbia
# * Delaware
# * Idaho
# * Michigan
# * Maine

# %%
#2018 SAT highest total mean score
final.sort_values('sat2018_total', ascending=False)[['state', 'sat2018_part_rate', 'sat2018_total']].head(10)
# Out:
#            state  sat2018_part_rate  sat2018_total
# 23     Minnesota               0.04           1298
# 49     Wisconsin               0.03           1294
# 34  North Dakota               0.02           1283
# 15          Iowa               0.03           1265
# 16        Kansas               0.04           1265
# 25      Missouri               0.04           1262
# 50       Wyoming               0.03           1257
# 27      Nebraska               0.03           1252
# 17      Kentucky               0.04           1248
# 41  South Dakota               0.03           1240

# %%
#2018 SAT lowest total mean score
final.sort_values('sat2018_total')[['state', 'sat2018_part_rate', 'sat2018_total']].head(10)
# Out:
#                    state  sat2018_part_rate  sat2018_total
# 8   District of Columbia               0.92            977
# 7               Delaware               1.00            998
# 48         West Virginia               0.28            999
# 12                 Idaho               1.00           1001
# 44                  Utah               0.04           1010
# 11                Hawaii               0.56           1010
# 22              Michigan               1.00           1011
# 19                 Maine               0.99           1013
# 39          Rhode Island               0.97           1018
# 13              Illinois               0.99           1019

# %% [markdown]
# For **2018 SAT**, the top 5 states with highest mean scores are: <br>
# * Minnesota
# * Winsconsin
# * North Dakota
# * Iowa
# * Kansas <br>
#
# The bottom 5 states with the lowest mean scores are: <br>
# * District of Columbia
# * Delaware
# * West Virginia
# * Idaho
# * Utah

# %% [markdown]
# **SAT Mean Score Observations** <br>
#
# Minnesota, Winsconsin and Iowa have always been in the top 5 in terms of mean total scores for 2017 and 2018. Conversely, District of Columbia, Delaware and Idaho have always been in the bottom 5. <br>
#
# It is worth noting that the lowest scoring states also happen to be the states with the highest participation rates. The highest scoring states also happen to have lower participation rates. <br>
#
# An exception to this would be West Virginia, with low participation and low mean score.
#
# This means there could be a negative correlation between participation rates and mean total scores for SAT.

# %% [markdown]
# # ACT mean Composite score and Observations

# %%
#2017 ACT highest composite mean score
final.sort_values('act_2017_avgscore', ascending=False)[['state', 'act2017_part_rate', 'act_2017_avgscore']].head(10)
# Out:
#                    state  act2017_part_rate  act_2017_avgscore
# 29         New Hampshire               0.18               25.5
# 21         Massachusetts               0.29               25.4
# 6            Connecticut               0.31               25.2
# 19                 Maine               0.08               24.3
# 8   District of Columbia               0.32               24.2
# 32              New York               0.31               24.2
# 22              Michigan               0.29               24.1
# 7               Delaware               0.18               24.1
# 39          Rhode Island               0.21               24.0
# 30            New Jersey               0.34               23.9

# %%
#2017 ACT lowest composite mean score
final.sort_values('act_2017_avgscore')[['state', 'act2017_part_rate', 'act_2017_avgscore']].head(10)
# Out:
#              state  act2017_part_rate  act_2017_avgscore
# 28          Nevada               1.00               17.8
# 24     Mississippi               1.00               18.6
# 40  South Carolina               1.00               18.7
# 11          Hawaii               0.90               19.0
# 33  North Carolina               1.00               19.1
# 0          Alabama               1.00               19.2
# 3         Arkansas               1.00               19.4
# 36        Oklahoma               1.00               19.4
# 18       Louisiana               1.00               19.5
# 2          Arizona               0.62               19.7

# %% [markdown]
# For **2017 ACT**, the top 5 states with highest mean scores are: <br>
# * New Hampshire
# * Massachusetts
# * Connecticut
# * Maine
# * District of Columbia <br>
#
# The bottom 5 states with the lowest mean scores are: <br>
# * Nevada
# * Mississippi
# * South Carolina
# * Hawaii
# * North Carolina

# %%
#2018 ACT highest composite mean score
final.sort_values('act_2018_avgscore', ascending=False)[['state', 'act2018_part_rate', 'act_2018_avgscore']].head(10)
# Out:
#             state  act2018_part_rate  act_2018_avgscore
# 6     Connecticut               0.26               25.6
# 21  Massachusetts               0.25               25.5
# 29  New Hampshire               0.16               25.1
# 32       New York               0.27               24.5
# 22       Michigan               0.22               24.4
# 39   Rhode Island               0.15               24.2
# 45        Vermont               0.24               24.1
# 19          Maine               0.07               24.0
# 46       Virginia               0.24               23.9
# 5        Colorado               0.30               23.9

# %%
#2018 ACT lowest composite mean score
final.sort_values('act_2018_avgscore')[['state', 'act2018_part_rate', 'act_2018_avgscore']].head(10)
# Out:
#              state  act2018_part_rate  act_2018_avgscore
# 28          Nevada               1.00               17.7
# 40  South Carolina               1.00               18.3
# 24     Mississippi               1.00               18.6
# 11          Hawaii               0.89               18.9
# 0          Alabama               1.00               19.1
# 33  North Carolina               1.00               19.1
# 2          Arizona               0.66               19.2
# 18       Louisiana               1.00               19.2
# 36        Oklahoma               1.00               19.3
# 3         Arkansas               1.00               19.4

# %% [markdown]
# For **2018 ACT**, the top 5 states with highest mean scores are: <br>
# * Connecticut
# * Massachusetts
# * New Hampshire
# * New York
# * Michigan <br>
#
# The bottom 5 states with the lowest mean scores are: <br>
# * Nevada
# * South Carolina
# * Mississippi
# * Hawaii
# * Alabama

# %% [markdown]
# **ACT Composite Mean Score Observations** <br>
#
# Connecticut, Massachusetts and New Hampshire have always been in the top 5 in terms of mean total scores for 2017 and 2018. Conversely, Nevada, Mississippi, South Carolina and Hawaii have always been in the bottom 5. <br>
#
# Similar to SAT, the lowest scoring states seem to be the states with the highest participation rates and vice versa. There could be a negative correlation between participation rates and composite mean scores for ACT.

# %% [markdown]
# # SAT and ACT changes in participation rate for states with 100 % participation

# %%
# SAT participation rate change
final['sat_part_change']= final['sat2018_part_rate'] - final['sat2017_part_rate']
final.sort_values('sat2017_part_rate',ascending=False)[['state','sat2017_part_rate','sat2018_part_rate','sat_part_change']].head(10)
# Out:
#                    state  sat2017_part_rate  sat2018_part_rate  \
# 8   District of Columbia               1.00               0.92
# 22              Michigan               1.00               1.00
# 6            Connecticut               1.00               1.00
# 7               Delaware               1.00               1.00
# 29         New Hampshire               0.96               0.96
# 19                 Maine               0.95               0.99
# 12                 Idaho               0.93               1.00
# 9                Florida               0.83               0.56
# 21         Massachusetts               0.76               0.80
# 39          Rhode Island               0.71               0.97
#
#     sat_part_change
# 8             -0.08
# 22             0.00
# 6              0.00
# 7              0.00
# 29             0.00
# 19             0.04
# 12             0.07
# 9             -0.27
# 21             0.04
# 39             0.26

# %% [markdown]
# ### I also want to know which states had the highest increase in SAT participation rate
# This is after seeing that Rhode Island had a really large increase in participation rate

# %%
final.sort_values('sat_part_change',ascending=False)[['state','sat2017_part_rate','sat2018_part_rate','sat_part_change']].head(10)
# Out:
#             state  sat2017_part_rate  sat2018_part_rate  sat_part_change
# 13       Illinois               0.09               0.99             0.90
# 5        Colorado               0.11               1.00             0.89
# 39   Rhode Island               0.71               0.97             0.26
# 48  West Virginia               0.14               0.28             0.14
# 30     New Jersey               0.70               0.82             0.12
# 32       New York               0.67               0.79             0.12
# 10        Georgia               0.61               0.70             0.09
# 20       Maryland               0.69               0.76             0.07
# 12          Idaho               0.93               1.00             0.07
# 4      California               0.53               0.60             0.07

# %% [markdown]
# ### **Observations on SAT participation rate** <br>
#
# * Michigan, Connecticut, Delaware showed no changes in participation rate from 2017
# * District of Columbia had a decrease in rate change by 8%
# * Illinois and Colorado had the largest increase in SAT participation thus far (by 89 and 90 % respectively). It could be that there were some policy changes that might have caused the surge.

# %%
#ACT participation rate change (17 states had 100% participation rate in 2017)
final['act_part_change'] = final['act2018_part_rate'] - final['act2017_part_rate']
final.sort_values('act2017_part_rate',ascending=False)[['state','act2017_part_rate','act2018_part_rate','act_part_change']].head(20)
# Out:
#              state  act2017_part_rate  act2018_part_rate  act_part_change
# 0          Alabama               1.00               1.00             0.00
# 17        Kentucky               1.00               1.00             0.00
# 49       Wisconsin               1.00               1.00             0.00
# 44            Utah               1.00               1.00             0.00
# 42       Tennessee               1.00               1.00             0.00
# 40  South Carolina               1.00               1.00             0.00
# 36        Oklahoma               1.00               1.00             0.00
# 33  North Carolina               1.00               1.00             0.00
# 28          Nevada               1.00               1.00             0.00
# 26         Montana               1.00               1.00             0.00
# 24     Mississippi               1.00               1.00             0.00
# 23       Minnesota               1.00               0.99            -0.01
# ...

# %% [markdown]
# ### Similar to SAT, I will also attempt to look at the largest increase in participation rate for ACT

# %%
final.sort_values('act_part_change',ascending=False)[['state','act2017_part_rate','act2018_part_rate','act_part_change']].head(20)
# Out:
#              state  act2017_part_rate  act2018_part_rate  act_part_change
# 35            Ohio               0.75               1.00             0.25
# 27        Nebraska               0.84               1.00             0.16
# 2          Arizona               0.62               0.66             0.04
# 20        Maryland               0.28               0.31             0.03
# 37          Oregon               0.40               0.42             0.02
# 15            Iowa               0.67               0.68             0.01
# 31      New Mexico               0.66               0.67             0.01
# 33  North Carolina               1.00               1.00             0.00
# 26         Montana               1.00               1.00             0.00
# 28          Nevada               1.00               1.00             0.00
# 0          Alabama               1.00               1.00             0.00
# 34    North Dakota               0.98               0.98             0.00
# ...

# %% [markdown]
# ### **Observations on ACT participation rate** <br>
#
# * Most states with 100% participation in 2017 showed little to no change in participation rate.
# * States with changes in participation include Minnesota (-1%), Hawaii (-1%), Colorado(-70%), and Illinois (-50%)
# * In the case of Colorado and Illinois, it could be due to participation rate increasing for SAT, which resulted in less students taking ACT.
# * Ohio and Nebraska had the largest increase in participation rate at 25% and 16 % respectively, increasing their ACT participation rate in 2018 to 100%

# %% [markdown]
# # States with >50 % participation on both tests either year

# %%
# 2017
final[(final['sat2017_part_rate'] > 0.5) & (final['act2017_part_rate'] > 0.5)][['state','sat2017_part_rate','act2017_part_rate']]
# Out:
#       state  sat2017_part_rate  act2017_part_rate
# 9   Florida               0.83               0.73
# 10  Georgia               0.61               0.55
# 11   Hawaii               0.55               0.90

# %% [markdown]
# For 2017, Florida, Georgia and Hawaii had more than 50% participation for SAT and ACT

# %%
# 2018
final[(final['sat2018_part_rate'] > 0.5) & (final['act2018_part_rate'] > 0.5)][['state','sat2018_part_rate','act2018_part_rate']]
# Out:
#              state  sat2018_part_rate  act2018_part_rate
# 9          Florida               0.56               0.66
# 10         Georgia               0.70               0.53
# 11          Hawaii               0.56               0.89
# 33  North Carolina               0.52               1.00
# 40  South Carolina               0.55               1.00

# %% [markdown]
# ### **Observations**
# For 2018, 2 more states had more than 50% participation for SAT and ACT, namely North and South Carolina (with ACT participation at 100%)

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %% [markdown]
# ## Correlation heatmap

# %%
#plot a heatmap 
plt.figure(figsize=(18,12))
plt.title("Correlation Heatmap for Combined ACT and SAT data\n")
sns.heatmap(final.corr(), annot=True, cmap="RdBu", center=0);

# %% [markdown]
# **Observations from correlation** <br>
#
# * There is a strong negative correlation (around 0.7 to 0.8) on mean/composite test scores with participation rates for both SAT and ACT for 2017 and 2018.
#
# * There is moderate positive correlation (around 0.6 to 0.76) on participation rate with mean/composite test scores from the other test. This means that high participation rate in SAT could see high scores in ACT.
#
# * There is a strong positive correlation (around 0.9 to 1.0) on mean scores for one section of the test with other sections of the same test or its total mean/composite score. This means that states that perform well in a particular section of the ACT for example, will also perform well in other sections of the ACT.

# %% [markdown]
# ## Histograms

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(18,12)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_title(list_of_titles[i])
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].axvline(x=dataframe[column].mean() , linewidth=2, color='k', linestyle='dashed')
        ax[i].axvline(x=dataframe[column].median() , linewidth=2, color='g', linestyle='dotted')
        min_ylim, max_ylim = ax[i].get_ylim()
        ax[i].text(x=dataframe[column].mean(), y=max_ylim*0.88, s='Mean', rotation=90, color='k')
        ax[i].text(x=dataframe[column].median(), y=max_ylim*0.85, s='Median', rotation=90, color='g')
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %% [markdown]
# ### **Observations on participation histograms**
#
# More states have 100% participation in ACT than in SAT. Participation below 10% is also more common in SAT than in ACT.
#
# However, participation in SAT picked up in 2018, with more states achieving 100% participation (from 7 in 2017 to 10 in 2018) and fewer states with less than 10% participation.

# %%
#count of states that achieved 90 to 100 percent participation in SAT in 2017
final[final['sat2017_part_rate'] >= 0.9].count()[0]
# Out:
# 7

# %%
#count of states that achieved 90 to 100 percent participation in SAT in 2018
final[final['sat2018_part_rate'] >= 0.9].count()[0]
# Out:
# 10

# %%
# Participation Rates for SAT & ACT

list_of_columns = ['act2017_part_rate', 'act2018_part_rate', 'sat2017_part_rate', 'sat2018_part_rate']
list_of_titles = ['ACT 2017', 'ACT 2018', 'SAT 2017', 'SAT 2018']
list_of_xlabels = ['participation rate', 'participation rate', 'participation rate', 'participation rate']

subplot_histograms(final, list_of_columns, list_of_titles, list_of_xlabels);

# %% [markdown]
# ### **Observations on histogram for Math Scores**
#
# The distributions look bimodal (two peaks) and right skewed, which is in line with our summary statistics where the median is smaller than the mean for all SAT and ACT math scores.<br>
# Compared to SAT math scores which look largely unchanged, ACT math scores have improved as the peak in 2018 has shifted to a range of around 19 - 20 compared to around 18.5 to 19 in 2017. <br>
# More states have also achieved ACT Math Scores in the range of around 23 to 23.5.

# %%
#Math scores for SAT and ACT


list_of_columns = ['act2017_math', 'act2018_math', 'sat2017_math', 'sat2018_math']
list_of_titles = ['ACT 2017 Math', 'ACT 2018 Math', 'SAT 2017 Math', 'SAT 2018 Math']
list_of_xlabels = ['score', 'score', 'score', 'score']

subplot_histograms(final, list_of_columns, list_of_titles, list_of_xlabels);

# %% [markdown]
# ### **Observations on histogram for Reading and Writing Scores**
#
# Similar to math scores, the distributions look bimodal. It also seems right skewed, given that the median is also smaller than the mean. <br>
# While the ACT scores seem to be largely unchanged, it seems like there are more states with SAT Evidence Based Reading and Writing scores in the range of 630 to 640.

# %%
#reading and verbal scores for ACT and SAT


list_of_columns = ['act2017_read', 'act2018_read', 'sat2017_read_write', 'sat2018_read_write']
list_of_titles = ['ACT 2017 Reading', 'ACT 2018 Reading', 'SAT 2017 Evidence Based Reading and Writing', 'SAT 2018 Evidence Based Reading and Writing']
list_of_xlabels = ['score', 'score', 'score', 'score']

subplot_histograms(final, list_of_columns, list_of_titles, list_of_xlabels);

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Custom scatterplot function
def scatterplot(column1, column2, x_label, y_label, title):
    plt.figure(figsize=(10,6))
    sns.set_style('darkgrid')
    sns.scatterplot(x = final[column1], y = final[column2])
    sns.regplot(x = final[column1], y = final[column2], data = final)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title);

# %% [markdown]
# ### Observations on scatterplot for 2017 Math scores, SAT vs ACT
#
# In the correlation heatmap, we have seen that there is weak negative correlation between the 2017 SAT and ACT math scores. The scatterplot confirms the inverse relationship between the two scores.

# %%
#SAT vs. ACT math scores for 2017

scatterplot('sat2017_math', 'act2017_math', 'SAT Math Score 2017', 'ACT Math Score 2017', 'Scatterplot of 2017 Math Scores, SAT vs ACT')

# %% [markdown]
# ### Observations on scatterplot for 2017 Reading and Writing scores, SAT vs ACT
#
# Similar to math scores, there is weak negative correlation between the 2017 SAT and ACT math scores. The scatterplot confirms the inverse relationship between the two scores.

# %%
#SAT vs. ACT verbal/reading scores for 2017

scatterplot('sat2017_read_write', 'act2017_read', 'SAT Evidence Based Read and Write Score', 'ACT Reading Score', 'Scatterplot of 2017 Reading and Writing Scores, SAT vs ACT')

# %% [markdown]
# ### Observations on scatterplot for 2017 Total Mean/Composite Scores, SAT vs ACT
#
# There is weak negative correlation between the 2017 SAT and ACT total mean/composite scores. The scatterplot confirms the inverse relationship between the two scores.

# %%
# SAT vs. ACT total/composite scores for 2017

scatterplot('sat2017_total', 'act_2017_avgscore', 'SAT Total Mean Score', 'ACT Composite Score', 'Scatterplot of 2017 Total Mean/Composite Scores, SAT vs ACT')

# %% [markdown]
# ### Observations on scatterplot for total mean scores, SAT 2017 vs SAT 2018
#
# There is strong positive correlation between the 2017 and 2018 SAT total mean scores. The scatterplot confirms the relationship between the two scores.
#
# Most data points are generally closer to the trend line, meaning that states scored close to how they did the previous year. There are some data points below the trend line, indicating that some states' scores worsened in 2018 significantly.

# %%
#Total scores for SAT 2017 vs. 2018
scatterplot('sat2017_total', 'sat2018_total', 'SAT 2017 Total Mean Score', 'SAT 2018 Total Mean Score', 'Scatterplot of Total Mean Scores, SAT2017 vs SAT2018')

# %% [markdown]
# ### Observations on scatterplot for composite scores, ACT 2017 vs ACT 2018
#
# There is strong positive correlation between the 2017 and 2018 SAT composite scores. The scatterplot confirms the relationship between the two scores.
#
# Similar to the SAT, the scatterplot shows that most states also scored close to how they did the previous year. However, the ACT plot appears to show fewer states significantly below the trend line. Moreover, there are states that improved scores significantly (they appear above the trend line).

# %%
#Composite scores for ACT 2017 vs. 2018

scatterplot('act_2017_avgscore', 'act_2018_avgscore', 'ACT 2017 Composite Score', 'ACT 2018 Composite Score', 'Scatterplot of Composite Scores, ACT2017 vs ACT2018')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %% [markdown]
# ### Observation of boxplot for participation
#
# As we observed previously in the summary statistics and the histograms:
# * There are no outliers in the data
# * The length of the box (Interquartile Range or IQR) for SAT in 2018 widened slightly to the right, which implies more states achieving higher SAT participation rates in 2018. <br>
# * The median of the boxes for ACT is higher that that of the boxes for SAT. This means that more states are taking up ACT compared to SAT. <br>
# * The median for SAT participation for both SAT boxes are located to the right of the centre of the box. This means the SAT participation rate follows a left skewed distribution. <br>
# * The median for both ACT boxes are located to the right of the centre of the box. This means the ACT participation rate follows a left skewed distribution. <br>
#
#
# More states are achieving higher SAT participation rates in 2018, but ACT participation rate in general is still higher across all states. This seems to imply that the ACT is gaining more traction than the SAT.

# %%
# Boxplot of SAT vs ACT Participation Rates
part_rates = final.loc[ : , ['sat2017_part_rate','sat2018_part_rate','act2017_part_rate','act2018_part_rate']]
plt.figure(figsize=(10,6))
plt.title('Boxplot of ACT and SAT Participation Rates, 2017 and 2018\n')
sns.boxplot(data=part_rates,orient='h',palette='Pastel2');

# %% [markdown]
# ### Observation of boxplot for SAT Scores
#
# * There are no outliers for the data.
# * The length of the box for SAT math scores (IQR) has shortened for 2018. This means that maths scores for SAT have worsened.
# * The IQR for Evidence Based Reading and Writing Scores span over a higher range and seems to be right skewed as the median is located to the left of the centre of the box. This means that students generally achieve better scores for this section of the test compared to SAT math.
# * For total mean scores, the median of SAT Total scores in 2017 is slightly higher compared to 2018.
# * The IQR for total mean score was also slightly wider in 2017 compared to 2018.

# %%
# Boxplot of SAT scores by section
sat_scores = final.loc[ : , ['sat2017_math', 'sat2018_math', 'sat2017_read_write', 'sat2018_read_write']]
plt.figure(figsize=(10,6))
plt.title('Boxplot of SAT score by section, 2017 and 2018\n')
sns.boxplot(data=sat_scores,orient='h',palette='Pastel2');

# Boxplot of SAT scores by total mean
sat_total_scores = final.loc[ : , ['sat2017_total', 'sat2018_total']]
plt.figure(figsize=(10,6))
plt.title('Boxplot of SAT score by total mean scores, 2017 and 2018\n')
sns.boxplot(data=sat_total_scores,orient='h',palette='Pastel2');

# %% [markdown]
# ### Observation of boxplot for ACT Scores
#
# * There are no outliers for the data.
# * The median score for English for both 2017 and 2018 are lower than the other sections. This implies that students generally achieve worse scores for English compared to other sections of the ACT.
# * The median scores for all sections of the ACT have decreased in 2018.
# * There does not seem to be a difference in the IQR for composite ACT scores in 2017 and 2018. This suggests that the scores have been generally constant for ACT.

# %%
# Boxplot of ACT scores by section
act_scores = final.loc[ : , ['act2017_eng', 'act2018_eng', 'act2017_math', 'act2018_math', 'act2017_read', 'act2018_read', 'act_2017_sci', 'act_2018_sci']]
plt.figure(figsize=(10,6))
plt.title('Boxplot of ACT score by section, 2017 and 2018\n')
sns.boxplot(data=act_scores,orient='h',palette='Pastel2');

# Boxplot of SAT scores by total mean
act_comp_scores = final.loc[ : , ['act_2017_avgscore', 'act_2018_avgscore']]
plt.figure(figsize=(10,6))
plt.title('Boxplot of ACT score by composite scores, 2017 and 2018\n')
sns.boxplot(data=act_comp_scores,orient='h',palette='Pastel2');

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# ### Exploring the relationship between total mean/composite scores vs participation rates

# %%
#SAT2017
scatterplot('sat2017_total', 'sat2017_part_rate', 'SAT 2017 Total Mean Score', 'SAT 2017 Participation Rate', 'Scatterplot of SAT mean total scores vs participation rate, 2017')

# %%
#SAT2018
scatterplot('sat2018_total', 'sat2018_part_rate', 'SAT 2018 Total Mean Score', 'SAT 2018 Participation Rate', 'Scatterplot of SAT mean total scores vs participation rate, 2018')
#plt.savefig("../images/Participation_Rates_Scatterplot_2018.png", bbox_inches='tight')

# %%
#ACT2017
scatterplot('act_2017_avgscore', 'act2017_part_rate', 'ACT 2017 Composite Score', 'ACT 2017 Participation Rate', 'Scatterplot of composite score vs participation rate for ACT, 2017')

# %%
#ACT2018
scatterplot('act_2018_avgscore', 'act2018_part_rate', 'ACT 2018 Composite Score', 'ACT 2018 Participation Rate', 'Scatterplot of composite score vs participation rate for ACT, 2018')

# %% [markdown]
# ### Observations from the scatterplot for score vs participation rate
#
# We noted from the earlier correlation heatmap that there is strong negative correlation between test scores and participation rate. However, after looking closer at the scatterplot, most data points do no fall near the trend line, and look widely spread. This implies that the correlation might not be as strong as we previously thought.
#
# Possible reasons for this phenomena could be that:
# * In states that have low participation rates, for example, high achieving students took the ACT/SAT voluntarily in order to gain admission to the colleges that imposed such admission requirements.
# * For states with high participation rates, it could be due to policy requirements that made the ACT/SAT mandatory but students were not provided sufficient time or assistance to prepare for the tests.

# %% [markdown]
# ### Exploring the relationship between ACT and SAT  participation rates

# %%
#SAT2017 vs ACT2017
scatterplot('sat2017_part_rate', 'act2017_part_rate', 'SAT 2017 Participation Rate', 'ACT 2017 Participation Rate', 'Scatterplot of participation rate for SAT vs ACT, 2017')

# %%
#SAT2018 vs ACT2018
scatterplot('sat2018_part_rate', 'act2018_part_rate', 'SAT 2018 Participation Rate', 'ACT 2018 Participation Rate', 'Scatterplot of participation rate for SAT vs ACT, 2018')

# %% [markdown]
# ### Observations from participation rates scatterplot
#
# There is a negative correlation between SAT and ACT participation rates, but it does not seem to be a strong correlation as only a few data points are near the trend line. This means that students who take ACT may also take the SAT.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ![image](../images/SAT_Participation_Rate_2017.png)

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe().T #recap on summary statistics
# Out:
#                     count         mean        std     min       25%      50%  \
# sat2017_part_rate    51.0     0.398039   0.352766    0.02     0.040     0.38
# sat2017_read_write   51.0   569.117647  45.666901  482.00   533.500   559.00
# sat2017_math         51.0   556.882353  47.121395  468.00   523.500   548.00
# sat2017_total        51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# act2017_part_rate    51.0     0.652549   0.321408    0.08     0.310     0.69
# act2017_eng          51.0    20.931373   2.353677   16.30    19.000    20.70
# act2017_math         51.0    21.182353   1.981989   18.00    19.400    20.90
# act2017_read         51.0    22.013725   2.067271   18.10    20.450    21.80
# act_2017_sci         51.0    21.450980   1.739353   18.20    19.950    21.30
# act_2017_avgscore    51.0    21.519608   2.020695   17.80    19.800    21.40
# sat2018_part_rate    51.0     0.457451   0.373143    0.02     0.045     0.52
# ...

# %% [markdown]
# Answers:
#
# ### Participation Rates <hr/>
# **SAT Participation Rates** <br>
# **Frequency:** We see from histograms plotted earlier that a large number of states fall within 0% to 10% participation rate. <br>
# **Mean:** The mean participation rates for 2017 and 2018 are around 39.8% and 45.7% respectively. <br>
# **Min-Max:** The minimum participation rate is 2% and maximum is 100% for both years. <br>
# **Skew:** The median participation rate for 2017 and 2018 is 38% and 52% respectively. The distribution for 2017 is right skewed, whereas the distribution for 2018 is left skewed. <br>
#
# **ACT Participation Rates** <br>
# **Frequency:** Our histogram plotted earlier shows us that a large number of states fall within 90% to 100% partcipation rate.<br> **Mean:** The mean participation rates for 2017 and 2018 are around 65.3% and 62% for 2017 and 2018 respectively. <br>
# **Min-Max:** The minimum participation rate for 2017 is 8% and maximum is 100%. The minimum participation rate for 2018 is 7% and maximum is 100% <br>
# **Skew:** The distribution for both years are left skewed. <br>
#
# **SAT vs ACT** <br>
# In comparison, ACT mean participation rates are higher than the SATs across all states. The skewness for SAT participation rate distributions has changed year to year which means that there is more take up for SATs, while the skewness for the ACT participation rate distributions seem to have remained constant. This suggests that ACT has a higher market share.

# %% [markdown]
# ### Total Mean Scores/Composite Scores <hr/>
#
# **SAT Total Mean Scores** <br>
# **Frequency:**  From the histogram plotted and the count below, we note that about 31 states scored below the mean in 2017 and 32 states scored below the mean in 2018.
# **Mean:** The mean scores for 2017 and 2018 are around 1126 and 1120 respectively. <br>
# **Min-Max:** For 2017 the min score is 950 and max score is 1295. For 2018, the min score is 977 and max score is 1298. <br>
# **Skew:**  The distribution looks bimodal (2 peaks) and is right skewed for both years. <br>
#
# **ACT Composite Scores** <br>
# **Frequency:** From the histogram plotted below, we note that about 28 states scored below the mean for both years. <br>
# **Mean:** The mean composite scores are about 21.5 for both years. <br>
# **Min-Max:** For 2017 the min score is 17.8 and max score is 25.5 For 2018 the min score 17.7 and max score is 25.6. This is in line with our boxplot observations that ACT scores have been constant. <br>
# **Skew:** The distribution is right skewed for both years.

# %%
#histogram for SAT mean total score and ACT composite scores

list_of_columns = ['sat2017_total', 'sat2018_total', 'act_2017_avgscore', 'act_2018_avgscore']
list_of_titles = ['SAT 2017', 'SAT 2018', 'ACT 2017', 'ACT 2018']
list_of_xlabels = ['score', 'score', 'score', 'score']

subplot_histograms(final, list_of_columns, list_of_titles, list_of_xlabels);

# %%
#find out how many states scored below mean for total mean SAT score in 2017
final[final['sat2017_total']<final['sat2017_total'].mean()].count()[0]
# Out:
# 31

# %%
#find out how many states scored below mean for total mean SAT score in 2018
final[final['sat2018_total']<final['sat2018_total'].mean()].count()[0]
# Out:
# 32

# %%
#find out how many states scored below mean for mean composite ACT score in 2017
final[final['act_2017_avgscore']<final['act_2017_avgscore'].mean()].count()[0]
# Out:
# 28

# %%
#find out how many states scored below mean for mean composite ACT score in 2018
final[final['act_2018_avgscore']<final['act_2018_avgscore'].mean()].count()[0]
# Out:
# 28

# %% [markdown]
# ###  Math Scores <hr/>
#
# **SAT Math Scores** <br>
# **Frequency:**  From the histogram plotted earlier and the count below, we note that about 31 states scored below the mean in 2017 and 32 states scored below the mean in 2018. <br>
# **Mean:** The mean score is around 556 for both years. <br>
# **Min-Max:** For 2017 the min score is 468 and max score is 651. For 2018, the min score is 480 and max score is 655. <br>
# **Skew:**  The distribution looks bimodal (2 peaks) and is right skewed for both years.
#
# **ACT Math Scores** <br>
# **Frequency:** From the histogram plotted earlier and the count below, we note that about 26 states scored below the mean in 2017 amd 28 states scored below the mean in 2018. <br>
# **Mean:** The mean math scores are about 21 for both years. <br>
# **Min-Max:** For 2017 the min score is 18 and max score is 25.3 For 2018 the min score 17.8 and max score is 25.2. <br>
# **Skew:** The distribution looks bimodal (2 peaks) and is right skewed for both years. <br>
#
# **SAT vs ACT Math Scores** <br>
# There are more states with below average math test scores in SAT than in ACT. This suggests that comparatively, students do not fare as well in the SAT Math.

# %%
#find out how many states scored below mean for sat math in 2017
final[final['sat2017_math'] < final['sat2017_math'].mean()].count()[0]
# Out:
# 31

# %%
#find out how many states scored below mean for sat math in 2018
final[final['sat2018_math'] < final['sat2018_math'].mean()].count()[0]
# Out:
# 32

# %%
#find out how many states scored below mean for act math in 2017
final[final['act2017_math'] < final['act2017_math'].mean()].count()[0]
# Out:
# 26

# %%
#find out how many states scored below mean for act math in 2018
final[final['act2018_math'] < final['act2018_math'].mean()].count()[0]
# Out:
# 28

# %% [markdown]
# ###  Reading Scores <hr/>
#
# **SAT Evidence Based Reading and Writing** <br>
# **Frequency:**  From the histogram plotted earlier and the count below, we note that about 31 states scored below the mean in 2017 and 30 states scored below the mean in 2018. <br>
# **Mean:** The mean score is around 569 for 2017 and 563 for 2018. <br>
# **Min-Max:** For 2017 the min score is 482 and max score is 644. For 2018, the min score is 480 and max score is 643.
# **Skew:**  The distribution looks bimodal (2 peaks) and is right skewed for both years. <br>
#
# **ACT Reading** <br>
# **Frequency:** From the histogram plotted earlier and the count below, we note that about 28 states scored below the mean for both years. <br>
# **Mean:** The mean reading scores are about 22 for both years. <br>
# **Min-Max:** the min score is about 18 and max score is about 26 for both years. <br>
# **Skew:** The distribution looks bimodal (2 peaks) and is right skewed for both years. <br>
#
# **SAT vs ACT Reading Scores** <br>
# There are more states with below average reading scores in SAT than in ACT. This suggests that comparatively, students do not fare as well in the SAT Evidence Based Reading and Writing section.

# %%
#find out how many states scored below mean for sat evidence based reading and writing in 2017
final[final['sat2017_read_write'] < final['sat2017_read_write'].mean()].count()[0]
# Out:
# 31

# %%
#find out how many states scored below mean for sat evidence based reading and writing in 2018
final[final['sat2018_read_write'] < final['sat2018_read_write'].mean()].count()[0]
# Out:
# 30

# %%
#find out how many states scored below mean for act reading in 2017
final[final['act2017_read'] < final['act2017_read'].mean()].count()[0]
# Out:
# 28

# %%
#find out how many states scored below mean for act reading in 2018
final[final['act2018_read'] < final['act2018_read'].mean()].count()[0]
# Out:
# 28

# %% [markdown]
# ###  ACT English and Science Scores <hr/>
#
# **ACT English** <br>
# **Frequency:**  From the histogram plotted and the count below, we note that about 28 states scored below the mean in 2017 and 29 states scored below the mean in 2018.
# **Mean:** The mean score is around 20.9 for both years. <br>
# **Min-Max:** For 2017 the min score is 16.3 and max score is 25.5. For 2018, the min score is 16.6 and max score is 26.
# **Skew:**  The distributions are right skewed for both years, but it is worth noting that the skew for the distribution seems more significant for 2018. This could mean that a large number of students fared better in ACT English in 2018.
#
# **ACT Science** <br>
# **Frequency:** From the histogram plotted earlier and the count below, we note that about 26 states scored below the mean for both years. <br>
# **Mean:** The mean reading scores are about 21.4 for 2017 and 21.3 for 2018. <br>
# **Min-Max:** The min score is about 18.2 and max score is about 24.9 for 2017. The min score is about 17.9 and max score is about 24.9 for 2018.  <br>
# **Skew:** The distribution looks right skewed for both years. <br>

# %%
#histogram for ACT English and Science scores

list_of_columns = ['act2017_eng', 'act2018_eng', 'act_2017_sci', 'act_2018_sci']
list_of_titles = ['ACT 2017 English', 'ACT 2018 English', 'ACT 2017 Science', 'ACT 2018 Science']
list_of_xlabels = ['score', 'score', 'score', 'score']

subplot_histograms(final, list_of_columns, list_of_titles, list_of_xlabels);

# %%
#find out how many states scored below mean for act english in 2017
final[final['act2017_eng'] < final['act2017_eng'].mean()].count()[0]
# Out:
# 28

# %%
#find out how many states scored below mean for act english in 2018
final[final['act2018_eng'] < final['act2018_eng'].mean()].count()[0]
# Out:
# 29

# %%
#find out how many states scored below mean for act science in 2017
final[final['act_2017_sci'] < final['act_2017_sci'].mean()].count()[0]
# Out:
# 26

# %%
#find out how many states scored below mean for act science in 2018
final[final['act_2018_sci'] < final['act_2018_sci'].mean()].count()[0]
# Out:
# 26

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# **Answer:** No we do not. We have observed from the earlier histograms of the different data variables, as well as the summary statistics that most distributions are right skewed. They therefore do not follow a normal distribution. This is evident based on the plots below for sat and act 2017 when observing the kde curve.

# %%
# plotting 
plt.figure(figsize=(16,6))

sns.displot(final['sat2017_part_rate'], kde=True);
sns.displot(final['act2017_part_rate'], kde=True);

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# **Answer:** As we have observed for Math, Reading and Participation from the various visualisations, they do not follow a normal distribution.
#
# For Math, the distributions for SAT and ACT for both years look bimodal and right skewed. <br>
# For Reading, the same can be observed. <br>
# For Participation, only SAT 2017 data is slightly right skewed. The rest of the data are left skewed. This is based on observation of the median in relation to the mean. <br>
#
# This means that using population parameters for a normal distribution to estimate the data will not be a good approximation of the real data.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# **Answer:** No it would not make sense to do so. The data is aggregated by state into 51 data points. This does not allow us to conduct random sampling or hypothesis testing to obtain [meaningful results.](http://www.tools4dev.org/resources/how-to-choose-a-sample-size/). Therefore, it might be better to obtain the data by district in each state.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# **Answer:** There are [concordance tables](https://www.act.org/content/dam/act/unsecured/documents/ACT-SAT-Concordance-Information.pdf) that have been published to convert and compare SAT and ACT scores. However, as the tests may have been formatted or set differently, it would still not be a good basis for comparison.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# ### Colorado
#
# From our previous exploratory analysis we realise that Colorado was one of the states with the highest gain in SAT participation rates, with an 89% increase. There is also a large decrease in ACT participation rate, at about 70%. Upon further research, we realised that it was because Colorado's education department and the College Board partnered to [mandate and administer the SAT starting April 2017.](https://www.testive.com/colorado-sat-change-2017/#:~:text=On%20April%2011th%2C%202017%20all,a%20new%20four%20hour%20exam.) Further, students could take the SAT at no cost.
#
# It is interesting to note that even though the SAT was mandated in 2017, there was still 30% ACT participation in 2018. This could be attributed to high achieving students who wanted to also take the ACTs for the purposes of college admission.

# %%
#getting participation rate for ACT and SAT for the state of colorado

final.loc[final['state'] == 'Colorado', ['state', 'sat2017_part_rate', 'sat2018_part_rate', 'sat_part_change', 'act2017_part_rate', 'act2018_part_rate', 'act_part_change']]
# Out:
#       state  sat2017_part_rate  sat2018_part_rate  sat_part_change  \
# 5  Colorado               0.11                1.0             0.89
#
#    act2017_part_rate  act2018_part_rate  act_part_change
# 5                1.0                0.3             -0.7

# %% [markdown]
# ### Illinois
#
# Similar to Colorado, Illinois also saw a huge increase in SAT participation rates from 2017 to 2018 (90%). There is also a large decrease in ACT participation rate by 50%. Upon external research, we realised that Illinois also partnered with the College Board to [mandate and administer the SAT starting April 5, 2017.](https://www.testive.com/illinois/) SAT was offered at no cost to the students.
#
# We also found out that the switch to SAT came as a shock to many of the schools in Illinois, because [Illinois was aligned with the ACT since 2001](https://patch.com/illinois/winnetka/sat-act-tips-offered-ahead-first-mandatory-state-exam), as evidenced by their participation rate of 93% in 2017. In fact, [ACT filed a protest with the Illinois State Board of Education](https://chicago.chalkbeat.org/2018/7/27/21105418/illinois-has-embraced-the-sat-and-the-act-is-mad-about-it) with regard to the switch. However, it is worth noting that there was a 43% ACT participation rate in 2018. Again, this could be due to high achieving students who wanted to also take the ACT to boost their chances for college admission.

# %%
#getting participation rate for ACT and SAT for the state of Illinois

final.loc[final['state'] == 'Illinois', ['state', 'sat2017_part_rate', 'sat2018_part_rate', 'sat_part_change', 'act2017_part_rate', 'act2018_part_rate', 'act_part_change']]
# Out:
#        state  sat2017_part_rate  sat2018_part_rate  sat_part_change  \
# 13  Illinois               0.09               0.99              0.9
#
#     act2017_part_rate  act2018_part_rate  act_part_change
# 13               0.93               0.43             -0.5

# %% [markdown]
# ### West Virginia
#
# West Virgina had a low participation rate in the SAT for 2017 and 2018, even though participation rate doubled to 28% in 2018. This makes it an interesting case study, because in 2017 the [West Virgina Department of Education chose the SAT as the new statewide standardized test.](https://www.wvgazettemail.com/news/education/wv-chooses-sat-as-new-high-school-standardized-test-for-juniors/article_b60d2618-4943-56f6-b180-4b4442172ef8.html)
#
# A reason for such low participation rates in the SAT could be that [most school administrators in the state were assuming that the ACT would still be the mandated test](https://www.wvgazettemail.com/news/education/wv-chooses-sat-as-new-high-school-standardized-test-for-juniors/article_b60d2618-4943-56f6-b180-4b4442172ef8.html), as it was what most students had taken in the past. More time might be required for schools to adjust and adapt to the SAT.

# %%
#getting participation rate for ACT and SAT for the state of West Virginia

final.loc[final['state'] == 'West Virginia', ['state', 'sat2017_part_rate', 'sat2018_part_rate', 'sat_part_change', 'act2017_part_rate', 'act2018_part_rate', 'act_part_change']]
# Out:
#             state  sat2017_part_rate  sat2018_part_rate  sat_part_change  \
# 48  West Virginia               0.14               0.28             0.14
#
#     act2017_part_rate  act2018_part_rate  act_part_change
# 48               0.69               0.65            -0.04

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# ### Conclusion <hr>
# From our exploration of the data, combined with external research, there are 3 key takeaways:
# 1) **Public policy is a key driver to increasing SAT participation rates**: As we have seen in the case of Colorado and Illinois, working with education boards or department of education in the respective states have helped to push SAT participation rates greatly. <br> <br>
# 2) **Increased participation rates are negatively correlated to test scores**: One of the reasons could be due to high achieving students taking both tests to boost their college admission chances. Another possible reason could be that with sudden mandates or changes in contracts, schools need time to adjust to the new test and prep their students to take it. This is why scores could dip in the short term. More data on scores over time would be required to examine if this is true.<br><br>
# 3) **SAT participation rate has seen some moderate success**: More states achieved 90% to 100% participation rates for SAT in 2018, from 7 in 2017 to 10 in 2018. More can be done to increase the participation rate in other states.

# %% [markdown]
# ### Recommendation <hr>
#
# Based on the above takeaways, we recommend that the College Board consider the following strategies:
#
# 1) **Target states that have yet to mandate any tests, and are more receptive towards SAT**: Based on this [article](https://magoosh.com/hs/sat/states-that-require-the-act-or-sat/), states on the map that are greyed out are currently not legally required to take the SAT or ACT. The College Board could consider working with the state department of education to administer and mandate the SAT in states that show a more favourable reception to the SAT. This way, we could provide schools with ample lead time to change their systems (unlike the case of West Virginia and Illinois where the school systems were more aligned to ACT). This could also help to improve SAT scores.

# %%
#show states that fit the above criteria
final[(final['sat_part_change'] > 0) & (final['act_part_change'] < 0)][['state', 'sat_part_change', 'act_part_change']]
# Out:
#             state  sat_part_change  act_part_change
# 1          Alaska             0.05            -0.32
# 4      California             0.07            -0.04
# 5        Colorado             0.89            -0.70
# 10        Georgia             0.09            -0.02
# 11         Hawaii             0.01            -0.01
# 12          Idaho             0.07            -0.02
# 13       Illinois             0.90            -0.50
# 19          Maine             0.04            -0.01
# 21  Massachusetts             0.04            -0.04
# 23      Minnesota             0.01            -0.01
# 30     New Jersey             0.12            -0.03
# 32       New York             0.12            -0.04
# 38   Pennsylvania             0.05            -0.03
# 39   Rhode Island             0.26            -0.06
# 43          Texas             0.04            -0.04
# 45        Vermont             0.04            -0.05
# 46       Virginia             0.03            -0.05
# ...

# %% [markdown]
# The states that fit the criteria are Washington, California, Alaska, New York, Pennsylvania, Georgia and Texas

# %% [markdown]
# 2) **Provide SAT School Day for schools in the abovementioned states**: The SAT costs [64.50 to take in 2018 with the optional essay component, and 47.50 without.](https://www.edmit.me/blog/how-much-does-it-cost-to-take-the-sat-how-much-does-it-cost-to-take-the-act#:~:text=SAT%20testing%20fees%20are%20set,optional%20essay%20component%20is%20%2464.50.) This could be a hefty sum for low income families. Therefore, introducing SAT School Days to offer the SAT at no cost to students could also increase the SAT participation rate.
#
# 3) **Help students become more aware of free resources, e.g. Khan Academy**: An increase in awareness of available tools and resources could help students better prepare for the SAT, and thus improve SAT scores and increase take up for SAT.
